# %% [markdown]
# FETCH MARKETS USING Gamma Market API

# %%
import requests
import pandas as pd
import json
import time

def fetch_polymarket_data(batch_size=500):
    """
    Fetch all Polymarket data using pagination
    
    Args:
        batch_size (int): Number of markets to fetch per request
    """
    try:
        all_markets = []
        offset = 0
        total_fetched = 0
        
        while True:
            # Make request with current offset
            url = f"https://gamma-api.polymarket.com/events?closed=false&limit={batch_size}&offset={offset}"
            print(f"Fetching events with offset {offset}...")
            
            r = requests.get(url)
            markets_list = r.json()
            
            # If no markets returned, we've reached the end
            if not markets_list:
                print("No more events available")
                break
            
            all_markets.extend(markets_list)
            total_fetched += len(markets_list)
            print(f"Fetched {len(markets_list)} events. Total so far: {total_fetched}")
            
            # If we got fewer markets than the batch size, we've reached the end
            if len(markets_list) < batch_size:
                break
                
            # Increment offset for next batch
            offset += batch_size
            
            # Small delay to be nice to the API
            time.sleep(0.5)
        
        # Convert to DataFrame
        df = pd.DataFrame(all_markets)
        
        # Sort by volume if available
        if 'volume' in df.columns:
            df = df.sort_values('volume', ascending=False)
        
        # Remove duplicates
        df = df.drop_duplicates(subset='id')
            
        print(f"\nTotal unique events fetched: {len(df)}")
        
        return df
        
    except Exception as e:
        print(f"Error fetching data: {str(e)}")
        return pd.DataFrame()

# Fetch and display the data
polymarket_df = fetch_polymarket_data(batch_size=500)
pd.set_option('display.max_columns', None)  # Show all columns
polymarket_df.head(10)

# Save to CSV
polymarket_df.to_csv('polymarket_events.csv', index=False)
# Out:
# Fetching events with offset 0...
# Fetched 500 events. Total so far: 500
# Fetching events with offset 500...
# Fetched 121 events. Total so far: 621
#
# Total unique events fetched: 621

# %% [markdown]
# Filter Markets to get only those of interest

# %%
##############################################################
# VOLUME FILTERING ############################################
##############################################################
# Convert volume to numeric, handling any non-numeric values
polymarket_df['volume'] = pd.to_numeric(polymarket_df['volume'], errors='coerce')

# Sort all values of volume in descending order
polymarket_df = polymarket_df.sort_values('volume', ascending=False)

# Filter to only include markets with volume greater than 200000
polymarket_df = polymarket_df[polymarket_df['volume'] > 1000000]

##############################################################
# GET SPECIFIC MARKETS #######################################
##############################################################
from ollama import chat
from ollama import ChatResponse
import ast

# Get unique labels to know what events to get
unique_labels = []
for i in polymarket_df['tags']:
    for j in i:
        if j["label"] not in unique_labels:
            unique_labels.append(j["label"])
print(len(unique_labels))


# Create the prompt
prompt = """Analyze these labels and identify those related to politics or finance, and make sure to AVOID any labels related to sports or entertainment.
Return ONLY a Python list containing the relevant labels, formatted exactly like this:
['label1', 'label2', 'label3']
No other text or explanation, just the list.
Labels: """ + str(unique_labels)

def get_relevant_labels(unique_labels, num_passes=3):
    all_relevant_labels = set()
    
    for _ in range(num_passes):
        response = chat(
            model='llama3.2',
            messages=[{
                'role': 'user',
                'content': prompt
            }],
        )
        
        try:
            labels = ast.literal_eval(response.message.content.strip())
            all_relevant_labels.update(labels)
        except (SyntaxError, ValueError) as e:
            print(f"Error parsing response: {e}")
            content = response.message.content.strip()
            content = content.replace('[', '').replace(']', '')
            labels = [label.strip().strip("'\"") for label in content.split(',')]
            all_relevant_labels.update(labels)
        
        time.sleep(1)  # Add small delay between requests
    
    return list(all_relevant_labels)

# Use the function
relevant_labels = get_relevant_labels(unique_labels)
print(f"Found {len(relevant_labels)} relevant labels:", relevant_labels)
# Out:
# 177
# Found 47 relevant labels: ['Iran', 'Zerohedge', 'International Relations', 'Russian Politics', 'Ukraine', 'Politics', 'Strategic Bitcoin Reserve', 'Prediction Markets', 'Macro Fed', 'Crypto Prices', 'Gov Shutdown', 'Yoon Suk Yeol', 'Crypto', 'Putin', 'prediction markets', 'Macro Geopolitics', 'Investments', 'Ethereum', 'World Elections', 'Stablecoins', 'US Election', 'Zelensky', 'Finance', 'Pete Hegseth', 'Middle East', 'Investment', 'Fed Rates', 'Trump Cabinet', 'Business', 'Elections', 'Commodities', 'Bitcoin', 'Trump Presidency', 'Economy', 'Ron Desantis', 'Global Politics', 'Global Elections', 'Macro Election 2', 'Markets', 'Geopolitics', 'Markt Cap', 'NATO', 'Russia', 'EU', 'Stock', 'finance', 'Creators']

# %% [markdown]
# Get columns of interest: clob token id, question, volume, active, description, tags, price, rewards, events

# %%
# parse the tags dictionary to filter those that are relevant
# Create an empty list to store the rows we want to keep
relevant_rows = []

# Iterate through the original dataframe
for index, row in polymarket_df.iterrows():
    # Check if any tag in this row's tags matches our relevant_labels
    tags = row['tags']
    if any(tag['label'] in relevant_labels for tag in tags):
        relevant_rows.append(row)

# Create new dataframe from the relevant rows
df = pd.DataFrame(relevant_rows)

# Reset the index of the new dataframe
df = df.reset_index(drop=True)

print(f"Found {len(df)} markets with relevant tags")
df.head(10)

markets_of_interest = df
# Out:
# Found 64 markets with relevant tags

# %%
for i in df['markets']:
    print(i)
# Out:
# [{'id': '511755', 'question': 'Will someone else be inaugurated?', 'conditionId': '0x21559998482bf5dfbcaf0f5409edd34eebd84c8998df622f9da8ff1e1f248a26', 'slug': 'will-someone-else-be-inaugurated', 'resolutionSource': '', 'endDate': '2025-01-20T12:00:00Z', 'liquidity': '167764.52061', 'startDate': '2024-11-01T22:46:40.903Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/who-will-be-inaugurated-Fnvq3D1ySaZa.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/who-will-be-inaugurated-Fnvq3D1ySaZa.jpg', 'description': 'This market will resolve to "Yes" if someone other than Kamala Harris or Donald J. Trump is inaugurated as President of the United States. Otherwise, this market will resolve to "No".\n\nInauguration day is currently scheduled for January 20, 2025. If inauguration day is delayed, this market will remain open until someone has been inaugurated. If no one has been inaugurated by January 31, 2025, 11:59 PM ET, this market will resolve to "Yes". \n\nThe primary resolution source for this market will be information from the US government, however a consensus of credible reporting will also be used.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0225", "0.9775"]', 'volume': '11404390.114471', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-11-01T21:18:14.303418Z', 'updatedAt': '2024-12-22T07:19:02.795431Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Other', 'groupItemThreshold': '2', 'questionID': '0x0e512a7a83b4e4d3f43b073af887341458922dd4b4929b7e0a4722d6c74a3f02', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 11404390.114471, 'liquidityNum': 167764.52061, 'endDateIso': '2025-01-20', 'startDateIso': '2024-11-01', 'hasReviewedDates': True, 'volume24hr': 348690.478494, 'clobTokenIds': '["55223339147513557002753346210723654663683660449692044699329423663012565950662", "43615071548148661312499725641130547187359327927736979074156645487662496301353"]', 'umaBond': '50000', 'umaReward': '50', 'volume24hrClob': 348690.478494, 'volumeClob': 11404390.114471, 'liquidityClob': 167764.52061, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0x0e512a7a83b4e4d3f43b073af887341458922dd4b4929b7e0a4722d6c74a3f00', 'negRiskRequestID': '0x8880fb7a2857bb2170e08d5587b40557b3881e4f5f37cdd432a0544524f04b2e', '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-11-01T22:45:09Z', 'cyom': False, 'competitive': 0.8143281029717886, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '9844', 'conditionId': '0x21559998482bf5dfbcaf0f5409edd34eebd84c8998df622f9da8ff1e1f248a26', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 10, 'startDate': '2024-11-01', 'endDate': '2500-12-31'}], 'rewardsMinSize': 10, 'rewardsMaxSpread': 1.5, 'spread': 0.001, 'oneDayPriceChange': -0.0005, 'lastTradePrice': 0.023, 'bestBid': 0.022, 'bestAsk': 0.023, 'automaticallyActive': True, 'clearBookOnStart': True, 'seriesColor': '', 'showGmpSeries': False, 'showGmpOutcome': False, 'manualActivation': False, 'negRiskOther': False}, {'id': '511753', 'question': 'Will Kamala Harris be inaugurated?', 'conditionId': '0xc5a29d7da91c765c5b8b45dc5f86147558ad0d16bb18e7ca14a74e3b5e3ebf9a', 'slug': 'will-kamala-harris-be-inaugurated', 'resolutionSource': '', 'endDate': '2024-12-20T12:00:00Z', 'liquidity': '803683.49211', 'startDate': '2024-11-01T22:45:12.663Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-harris-be-inaugurated-cqJudvUN6N7G.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-kamala-harris-be-inaugurated-cqJudvUN6N7G.jpg', 'description': 'This market will resolve to "Yes" if Kamala Harris is inaugurated as President of the United St ...
# [{'id': '254248', 'question': "Will 'Deadpool 3' gross most in 2024?", 'conditionId': '0xbce0ff6f8ee396ec39e76c8b60d747272e8bf4bd65f31d0e131b64aceb0be3b5', 'slug': 'will-deadpool-3-gross-most-in-2024', 'resolutionSource': '', 'endDate': '2024-12-29T00:00:00Z', 'liquidity': '461110.05341', 'startDate': '2024-01-31T23:47:00Z', 'fee': '20000000000000000', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/deadpool.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/deadpool.png', 'description': 'This market will resolve to "Yes" if the "Gross" column on https://www.boxofficemojo.com/year/2024/?grossesOption=calendarGrosses shows \'Deadpool 3\' (2024) as the film with the highest 2024 gross once data for December 31 is made available. Otherwise, this market will resolve to "No".\n\nNote: This market is about the movie\'s domestic calendar gross in 2024 - dates outside of 2024 will not count toward this movie\'s gross. \n\nIn the event of an exact tie the film that comes first alphabetically will be considered the winner.\n\nIf there is no final data available by January 7, 2025, 11:59 PM ET, another credible resolution source will be chosen.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0015", "0.9985"]', 'volume': '6558762.27157993', 'active': True, 'marketType': 'normal', 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-01-31T22:05:51.691Z', 'updatedAt': '2024-12-22T07:18:41.537303Z', 'wideFormat': False, 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Deadpool 3', 'groupItemThreshold': '3', 'questionID': '0x3f3ae07223492f5ba2e46adba8c64c98df1995a1002d78f96434611a4b459202', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 6558762.27157993, 'liquidityNum': 461110.05341, 'endDateIso': '2024-12-29', 'startDateIso': '2024-01-31', 'hasReviewedDates': True, 'commentsEnabled': False, 'volume24hr': 277663.089, 'secondsDelay': 0, 'clobTokenIds': '["10121150820228421248893179951676281814158596154979528998074907576296371458438", "61111845596144826019799073782298606899058648885167941219160994016138099600108"]', 'umaBond': '500.0', 'umaReward': '5.0', 'fpmmLive': True, 'volume24hrClob': 277663.089, 'volumeClob': 6558762.27157993, 'liquidityClob': 461110.05341, 'makerBaseFee': 0, 'takerBaseFee': 0, 'customLiveness': 0, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0x3f3ae07223492f5ba2e46adba8c64c98df1995a1002d78f96434611a4b459200', 'negRiskRequestID': '0x4387722600154f2e4903295cd6d2a1f3ad0475420dbc791d7a7dad2e4f3045cf', 'notificationsEnabled': True, '_sync': False, 'creator': '', 'ready': False, 'funded': False, 'cyom': False, 'competitive': 0.8009597099244316, 'pagerDutyNotificationEnabled': False, 'approved': True, 'rewardsMinSize': 200, 'rewardsMaxSpread': 3.5, 'spread': 0.001, 'lastTradePrice': 0.001, 'bestBid': 0.001, 'bestAsk': 0.002, 'automaticallyActive': True, 'clearBookOnStart': True, 'manualActivation': False, 'negRiskOther': False}, {'id': '254250', 'question': "Will 'Joker 2' gross most in 2024?", 'conditionId': '0x87ebcc9f6660a5b9613650c3d91bae01f4503b11eb61a782b993bbc3a5d41b04', 'slug': 'will-joker-2-gross-most-in-2024', 'resolutionSource': '', 'endDate': '2024-12-29T00:00:00Z', 'liquidity': '799794.66121', 'startDate': '2024-01-31T23:47:00Z', 'fee': '20000000000000000', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/joker+2.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/joker+2.png', 'description': 'This market will resolve to "Yes" if the "Gross" column on https://www.boxofficemojo.com/year/2024/?grossesOption=calendarGrosses shows \'Joker: Folie à Deux\' (2024) as the film with the highest 2024 gross once data for December 31 is made available. Otherwise, this market will resolve to "No".\n\nNote: This market is about the mo ...
# [{'id': '503013', 'question': 'Will Biden finish his term?', 'conditionId': '0xd1e760f57415093db2e8378b79fe37ec8dc9ad09ee57f6f0cdc2468ae29fea23', 'slug': 'will-biden-complete-his-term-as-president', 'resolutionSource': '', 'endDate': '2025-01-20T12:00:00Z', 'liquidity': '820246.4613', 'startDate': '2024-06-28T21:55:53.464Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-biden-complete-his-term-as-president-ef7MVl4ncDiT.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-biden-complete-his-term-as-president-ef7MVl4ncDiT.jpg', 'description': 'This market will resolve to "Yes" if Joe Biden successfully finishes his term as President of the United States of America without any interruptions. Otherwise, this market will resolve to "No".\n\nThis market will not resolve "Yes" until the presidency is successfully transferred from Biden to another person at the completion of his term on January 20, 2025, or until Biden is sworn into the presidency again on that date.\n\nThe primary resolution source for this market is official information from the US federal government, however a consensus of credible reporting will also be used.  ', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.945", "0.055"]', 'volume': '46653600.1324712', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-06-28T20:58:53.038399Z', 'updatedAt': '2024-12-22T07:18:37.506193Z', 'new': False, 'featured': True, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '', 'groupItemThreshold': '0', 'questionID': '0x2b8a133e7b9b118aec4872b57d096aba941014b82740895b1bc3c7a7da2615b2', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.01, 'orderMinSize': 5, 'volumeNum': 46653600.1324712, 'liquidityNum': 820246.4613, 'endDateIso': '2025-01-20', 'startDateIso': '2024-06-28', 'hasReviewedDates': True, 'volume24hr': 134294.950062, 'clobTokenIds': '["76018684495672907293972579038657312280524447899213220717960084627380959769440", "100180144441344516029196380796541367659775855719836481414910537902981560041958"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 134294.950062, 'volumeClob': 46653600.1324712, 'liquidityClob': 820246.4613, 'acceptingOrders': True, 'negRisk': False, '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-06-28T21:38:25Z', 'cyom': False, 'competitive': 0.8347071221385196, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '2770', 'conditionId': '0xd1e760f57415093db2e8378b79fe37ec8dc9ad09ee57f6f0cdc2468ae29fea23', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 200, 'startDate': '2024-06-28', 'endDate': '2500-12-31'}], 'rewardsMinSize': 100, 'rewardsMaxSpread': 3.5, 'spread': 0.01, 'oneDayPriceChange': 0.01, 'lastTradePrice': 0.95, 'bestBid': 0.94, 'bestAsk': 0.95, 'automaticallyActive': True, 'clearBookOnStart': True, 'manualActivation': False, 'negRiskOther': False}]
# [{'id': '512953', 'question': 'Will Jim Jordan be the first elected Speaker of the House for the 119th congress?', 'conditionId': '0x8a2af36b760cae72ad72ce391429a3599923ea0c5c91f0f7a0e8e834d0e2a518', 'slug': 'will-jim-jordan-be-the-first-elected-speaker-of-the-house-for-the-119th-congress', 'resolutionSource': '', 'endDate': '2025-06-30T12:00:00Z', 'liquidity': '20662.75327', 'startDate': '2024-11-13T00:49:50.05034Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-jim-jordan-be-the-first-elected-speaker-of-the-house-for-the-119th-congress-ZA6X2Anllfoi.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-jim-jordan-be-the-first-elected-speaker-of-the-house-for-the-119th-congress-ZA6X2Anllfoi.jpg', 'description': 'This market will resolve to "Yes" if Jim Jordan becomes the first-elected Speaker of the House in the 119th United States Congress. Otherwise, this market will resolve to "No".\n\nAny individual elected to be, appointed to be, or serving as Speaker pro tempore in the 119th congress will have no bearing on the resolution of this market. Only the first-elected Speaker of the House will count toward the resolution of this market.\n\nIf the election for the first Speaker for the 119th Congress is not finalized by June 30, 2025, 11:59 PM ET, this market will resolve to "No".\n\nThe primary resolution source for this market will be official information from the government of the United States of America (ex: https://www.speaker.gov/, https://www.house.gov/), however credible reporting may be used.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0845", "0.9155"]', 'volume': '228880.302814997', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-11-13T00:45:05.793268Z', 'updatedAt': '2024-12-22T07:19:02.494014Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Jim Jordan', 'groupItemThreshold': '9', 'questionID': '0x8ebd288d1ef9dd5df6d98c2f423107c8059006d893d1839a514534901d534709', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 228880.302814997, 'liquidityNum': 20662.75327, 'endDateIso': '2025-06-30', 'startDateIso': '2024-11-13', 'hasReviewedDates': True, 'volume24hr': 15964.184461, 'clobTokenIds': '["2951239175820818966774786476577799016487897147861706947302508664495696078925", "31741510781665915751028101050476924521505086757877688353179804699700683378853"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 15964.184461, 'volumeClob': 228880.302814997, 'liquidityClob': 20662.75327, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0x8ebd288d1ef9dd5df6d98c2f423107c8059006d893d1839a514534901d534700', 'negRiskRequestID': '0x06edc8bc29cb0ac2c782ea17e009a2cf872d9295dc823022c991018bbfdaf959', '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-11-13T00:48:36Z', 'cyom': False, 'competitive': 0.8527764589352957, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '10428', 'conditionId': '0x8a2af36b760cae72ad72ce391429a3599923ea0c5c91f0f7a0e8e834d0e2a518', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 30, 'startDate': '2024-11-13', 'endDate': '2500-12-31'}], 'rewardsMinSize': 50, 'rewardsMaxSpread': 3.5, 'spread': 0.003, 'oneDayPriceChange': -0.0365, 'lastTradePrice': 0.084, 'bestBid': 0.083, 'bestAsk': 0.086, 'automaticallyActive': True, 'clearBookOnStart': True, 'seriesColor': '', 'showGmpSeries': False, 'showGmpOutcome': False, 'manualActivation': False, 'negRiskOther': False}, {'id': '513460', 'question': 'Will Byron Donalds be the first elected Speaker of the House for the 119th congress?', 'conditionId': '0x39ea2c78a19e57d5c1de6e5180c039038a6a1a9c483f10e370f242b3da207b4e', 'slug': 'will-byron-donalds-be-the-first-elected-spe ...
# [{'id': '512337', 'question': 'Will Mircea Geoană win the 2024 Romanian Presidential election?', 'conditionId': '0x6a697a68bc06abf48bdd3116d8b6263d59afa2952ed6900824f42b109a4adcde', 'slug': 'will-mircea-geoana-win-the-2024-romanian-presidential-election', 'resolutionSource': '', 'endDate': '2024-12-08T12:00:00Z', 'liquidity': '110769.23529', 'startDate': '2024-11-08T00:11:21.908707Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-mircea-geoan-win-the-2024-romanian-presidential-election-d7MzxDaK4pmI.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-mircea-geoan-win-the-2024-romanian-presidential-election-d7MzxDaK4pmI.jpg', 'description': 'Presidential elections will be held in Romania on 24 November 2024. A second round will be held on 8 December 2024 if no candidate receives an absolute majority of the vote.\n\nThis market will resolve to "Yes" if Mircea Geoană wins this election. Otherwise, this market will resolve to "No".\n\nThis market includes any potential second round. If the result of this election isn\'t known by April 30, 2025, 11:59 PM ET, the market will resolve to "No".\n\nThis market will resolve solely based off the first official announcement of the election results from the Romanian Government, specifically the Permanent Electoral Authority (https://www.roaep.ro/prezentare/).\n', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0035", "0.9965"]', 'volume': '2024006.214668', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-11-07T23:29:18.28633Z', 'updatedAt': '2024-12-22T07:18:40.318245Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Mircea Geoană', 'groupItemThreshold': '0', 'questionID': '0xddf50ca1c4e44048b231fbcaba42b1d5d39b155be73bcb67849a4bf2ea890500', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 2024006.214668, 'liquidityNum': 110769.23529, 'endDateIso': '2024-12-08', 'startDateIso': '2024-11-08', 'hasReviewedDates': True, 'volume24hr': 2933.030332, 'clobTokenIds': '["88761004125801121170646830098793737944899672743449695591428365330803191629513", "31841501356406363357248311485973323507088331580851078508835563887196938396484"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 2933.030332, 'volumeClob': 2024006.214668, 'liquidityClob': 110769.23529, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0xddf50ca1c4e44048b231fbcaba42b1d5d39b155be73bcb67849a4bf2ea890500', 'negRiskRequestID': '0x318461b77b9124b27692e145ae7783ed1269578ab01abddcbc653f02d193c56a', '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-11-08T00:10:14Z', 'cyom': False, 'competitive': 0.8022384055993032, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '11405', 'conditionId': '0x6a697a68bc06abf48bdd3116d8b6263d59afa2952ed6900824f42b109a4adcde', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 10, 'startDate': '2024-12-06', 'endDate': '2500-12-31'}], 'rewardsMinSize': 50, 'rewardsMaxSpread': 3.5, 'spread': 0.001, 'oneDayPriceChange': -0.001, 'lastTradePrice': 0.004, 'bestBid': 0.003, 'bestAsk': 0.004, 'automaticallyActive': True, 'clearBookOnStart': True, 'seriesColor': '', 'showGmpSeries': False, 'showGmpOutcome': False, 'manualActivation': False, 'negRiskOther': False}, {'id': '512338', 'question': 'Will Marcel Ciolacu win the 2024 Romanian Presidential election?', 'conditionId': '0xa2f0eb0b70c25a2f4c5c0493b593a36c35d3fe964e51f306ec0ad1f76be2da85', 'slug': 'will-marcel-ciolacu-win-the-2024-romanian-presidential-election', 'resolutionSource': '', 'endDate': '2024-12-08T12:00:00Z', 'liquidity': '79158.22269', 'startDate': '2024-11-08T00:12:45.177Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-marcel-cio ...
# [{'id': '514366', 'question': 'Will Bitcoin reach $100,000 in December?', 'conditionId': '0x9621f12e621ac9ec3d556accb7e1af020d04f62538873e7f1f9630aa246b5470', 'slug': 'will-bitcoin-reach-100000-in-december', 'resolutionSource': '', 'endDate': '2024-12-31T12:00:00Z', 'startDate': '2024-12-02T16:37:11.177Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-price-will-bitcoin-hit-in-december-Hb1lLfWBux4I.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-price-will-bitcoin-hit-in-december-Hb1lLfWBux4I.jpg', 'description': 'This market will immediately resolve to "Yes" if any Binance 1 minute candle for Bitcoin (BTCUSDT) between December 2, 2024, 00:00 and December 31, 2024, 23:59 in the ET timezone has a final "High" price of $100,000.00 or higher. Otherwise, this market will resolve to "No."\n\nThe resolution source for this market is Binance, specifically the BTCUSDT "High" prices available at https://www.binance.com/en/trade/BTC_USDT, with the chart settings on "1m" for one-minute candles selected on the top bar.\n\nPlease note that the outcome of this market depends solely on the price data from the Binance BTCUSDT trading pair. Prices from other exchanges, different trading pairs, or spot markets will not be considered for the resolution of this market.\n', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["1", "0"]', 'volume': '213981.714901', 'active': True, 'closed': True, 'marketMakerAddress': '', 'createdAt': '2024-12-02T16:07:48.186008Z', 'updatedAt': '2024-12-06T03:57:34.484087Z', 'closedTime': '2024-12-05 04:46:16+00', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '$100k', 'groupItemThreshold': '4', 'questionID': '0x0f396cbeef2a2a9cb3efacbd62f8ed4190583ab3248cbe0e28fc5a34e3265730', 'umaEndDate': '2024-12-05T04:46:16Z', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'umaResolutionStatus': 'resolved', 'volumeNum': 213981.714901, 'endDateIso': '2024-12-31', 'startDateIso': '2024-12-02', 'hasReviewedDates': True, 'clobTokenIds': '["17268373011438876626874317939671582683511408810378790963424068020204662683971", "26509904449072038660246625232668712511651545020352664857753896458207580360784"]', 'umaBond': '500', 'umaReward': '5', 'volumeClob': 213981.714901, 'acceptingOrders': False, 'negRisk': False, '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-12-02T16:36:00Z', 'cyom': False, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '11124', 'conditionId': '0x9621f12e621ac9ec3d556accb7e1af020d04f62538873e7f1f9630aa246b5470', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 10, 'startDate': '2024-12-02', 'endDate': '2500-12-31'}], 'rewardsMinSize': 20, 'rewardsMaxSpread': 3.5, 'spread': 0.001, 'automaticallyResolved': True, 'oneDayPriceChange': 0.3295, 'lastTradePrice': 1, 'bestBid': 0.999, 'bestAsk': 1, 'automaticallyActive': True, 'clearBookOnStart': True, 'seriesColor': '', 'showGmpSeries': False, 'showGmpOutcome': False, 'manualActivation': False, 'negRiskOther': False}, {'id': '514367', 'question': 'Will Bitcoin reach $105,000 in December?', 'conditionId': '0xc54c0a7a9914e36e4b369ce6d5dae60eed4c8c9c6a5d78599d9d65804b2c947d', 'slug': 'will-bitcoin-reach-105000-in-december', 'resolutionSource': '', 'endDate': '2024-12-31T12:00:00Z', 'startDate': '2024-12-02T16:36:41.289Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-price-will-bitcoin-hit-in-december-Hb1lLfWBux4I.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/what-price-will-bitcoin-hit-in-december-Hb1lLfWBux4I.jpg', 'description': 'This market will immediately resolve to "Yes" if any Binance 1 minute candle for Bitcoin (BTCUSDT) between December 2, 2024, 00:00 and December 31, 2024, 2 ...
# [{'id': '506202', 'question': 'Will there be a US Government shutdown? ', 'conditionId': '0x87d67272f0ce1bb0d80ba12a1ab79287b2a235a5f361f5bcbc06ea0ce34e61c5', 'slug': 'us-government-shutdown-before-2025', 'resolutionSource': '', 'endDate': '2024-12-31T12:00:00Z', 'liquidity': '1539234.78991', 'startDate': '2024-09-03T16:16:55.822Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/us-government-shutdown-before-2025-yVCKpcD8dJmu.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/us-government-shutdown-before-2025-yVCKpcD8dJmu.jpg', 'description': 'This market will resolve to "Yes" if the U.S government shut down occurs between August 30, and December 31, 2024, 11:59 PM ET. Otherwise, this market will resolve to "No". \n\nThe market will resolve to “Yes” if the acting President fails to sign the relevant bill(s) extending government funding by the applicable deadline(s), even if no government shutdown is explicitly announced. \n\nFor this market to resolve to "Yes" any shutdown will count. If only a portion of the US government is covered by any signed bill(s) extending funding of the US government, and a portion of the US government goes unfunded, this market will still resolve to "Yes". \n\n The primary resolution for this source will be official information from the US government, however a consensus of credible reporting may also be used.  \n\n', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.994", "0.006"]', 'volume': '21083275.280311', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-08-31T20:30:49.284344Z', 'updatedAt': '2024-12-22T07:20:18.186029Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '', 'groupItemThreshold': '0', 'questionID': '0x1c297f2aff66cf00d2e018105b7cb25b0993aea36f518b382d9fda524e8122ab', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'umaResolutionStatus': 'disputed', 'volumeNum': 21083275.280311, 'liquidityNum': 1539234.78991, 'endDateIso': '2024-12-31', 'startDateIso': '2024-09-03', 'hasReviewedDates': True, 'volume24hr': 11096413.544053, 'gameStartTime': '2024-12-21 15:42:00+00', 'clobTokenIds': '["25788984364015292223605977307142748201985724991469784186655292374059222006895", "61870696561549212427703774084341694590597083144015451858728593820052569648622"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 11096413.544053, 'volumeClob': 21083275.280311, 'liquidityClob': 1539234.78991, 'acceptingOrders': True, 'negRisk': False, '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-09-03T16:15:45Z', 'cyom': False, 'competitive': 0.8038352587867232, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '5538', 'conditionId': '0x87d67272f0ce1bb0d80ba12a1ab79287b2a235a5f361f5bcbc06ea0ce34e61c5', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 600, 'startDate': '2024-09-03', 'endDate': '2500-12-31'}], 'rewardsMinSize': 50, 'rewardsMaxSpread': 3.5, 'spread': 0.002, 'oneDayPriceChange': 0.016, 'lastTradePrice': 0.995, 'bestBid': 0.993, 'bestAsk': 0.995, 'automaticallyActive': True, 'clearBookOnStart': True, 'manualActivation': False, 'negRiskOther': False}]
# [{'id': '254432', 'question': 'Ethereum all time high in 2024?', 'conditionId': '0x5401278f7f9c9df79552148e2b280dea9ea91431a77c2c46686b8bec598970e7', 'slug': 'ethereum-all-time-high-in-2024', 'resolutionSource': 'https://www.binance.com/en/trade/ETH_USDT', 'endDate': '2024-12-30T12:00:00Z', 'liquidity': '414616.05997', 'startDate': '2024-02-12T22:33:41.667Z', 'fee': '20000000000000000', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/DALL%C2%B7E+2024-02-12+15.14.23+-+Envision+an+even+more+surreal+and+captivating+scene%2C+where+the+Ethereum+logo%2C+now+significantly+larger%2C+dominates+the+sky+as+the+central+sun+in+a+brea.webp', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/DALL%C2%B7E+2024-02-12+15.14.23+-+Envision+an+even+more+surreal+and+captivating+scene%2C+where+the+Ethereum+logo%2C+now+significantly+larger%2C+dominates+the+sky+as+the+central+sun+in+a+brea.webp', 'description': 'This market will resolve to "Yes" if Ethereum (ETH) reaches a price greater than $4,868.00 according to Binance by December 31, 2024, 11:59 PM ET. Otherwise, this market will resolve to "No".\n\nThe resolution source for this market will be the 30-min candlestick high prices from Binance (https://www.binance.com/en/trade/ETH_USDT). If Binance is unavailable, a consensus of other credible sources will be used.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0225", "0.9775"]', 'volume': '14896296.2104252', 'active': True, 'marketType': 'normal', 'closed': False, 'marketMakerAddress': '0x1b87C310C0efe54a721a2396Cec6Fac1230a19ed', 'createdAt': '2024-02-12T21:15:20.422Z', 'updatedAt': '2024-12-22T07:19:09.2903Z', 'wideFormat': False, 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '', 'groupItemThreshold': '0', 'questionID': '0xa166b92160e863aef03826c67002886e5359393ba5c44bb3a0cca69b27dcb347', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 14896296.2104252, 'liquidityNum': 414616.05997, 'endDateIso': '2024-12-31', 'startDateIso': '2024-02-12', 'hasReviewedDates': True, 'commentsEnabled': False, 'volume24hr': 336924.624157, 'secondsDelay': 0, 'clobTokenIds': '["104384626333890484417631221426453974917579250857486058586575825503557175219318", "21141504331828146088416065151083242350756843661701373107647465798821590056635"]', 'umaBond': '500.0', 'umaReward': '5.0', 'fpmmLive': True, 'volume24hrClob': 336924.624157, 'volumeClob': 14896296.2104252, 'liquidityClob': 414616.05997, 'makerBaseFee': 0, 'takerBaseFee': 0, 'customLiveness': 0, 'acceptingOrders': True, 'negRisk': False, 'notificationsEnabled': True, '_sync': False, 'creator': '', 'ready': False, 'funded': False, 'cyom': False, 'competitive': 0.8143281029717886, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '10416', 'conditionId': '0x5401278f7f9c9df79552148e2b280dea9ea91431a77c2c46686b8bec598970e7', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 10, 'startDate': '2024-11-12', 'endDate': '2500-12-31'}], 'rewardsMinSize': 200, 'rewardsMaxSpread': 3.5, 'spread': 0.005, 'oneDayPriceChange': -0.0145, 'lastTradePrice': 0.024, 'bestBid': 0.02, 'bestAsk': 0.025, 'automaticallyActive': True, 'clearBookOnStart': True, 'manualActivation': False, 'negRiskOther': False}]
# [{'id': '514138', 'question': 'Will Karol Nawrocki be the next President of Poland?', 'conditionId': '0x5ce0d897bd66142c43a38204a67ad85bc3e0643382258411a5aa58ca3e825082', 'slug': 'will-karol-nawrocki-be-the-next-president-of-poland', 'resolutionSource': '', 'endDate': '2025-05-18T12:00:00Z', 'liquidity': '30420.1094', 'startDate': '2024-11-26T23:47:32.210711Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-karol-nawrocki-be-the-next-president-of-namibia-z_eSKTcwRkOu.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-karol-nawrocki-be-the-next-president-of-namibia-z_eSKTcwRkOu.jpg', 'description': 'Presidential elections will be held in Poland in May, 2025. If no candidate receives a majority in the first round, a second round will be held.\n\nThis market will resolve to "Yes" if Karol Nawrocki wins this election. Otherwise, this market will resolve to "No".\n\nThis market includes any potential second round. If the result of this election isn\'t known by July 31, 2025, 11:59 PM ET, the market will resolve to "No".\n\nThis market will resolve solely based off the first official announcement of the winner of the election from the Polish government, specifically the National Electoral Commission (Państwowa Komisja Wyborcza, PKW) (https://www.pkw.gov.pl/).\n', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.29", "0.71"]', 'volume': '141429.268593', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-11-26T15:44:20.868949Z', 'updatedAt': '2024-12-22T07:18:44.264177Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Karol Nawrocki', 'groupItemThreshold': '0', 'questionID': '0x6df9c389b900084450acb3df5777dcde9ff74f6a1532e9d78a715b5ee83dda12', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.01, 'orderMinSize': 5, 'volumeNum': 141429.268593, 'liquidityNum': 30420.1094, 'endDateIso': '2025-05-18', 'startDateIso': '2024-11-26', 'hasReviewedDates': True, 'volume24hr': 2875.62284, 'clobTokenIds': '["52378310446953465163845338048369876961360578335284428810587513450420811578746", "12000674920991755992211074758866949296981843307621554385852540153569787669909"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 2875.62284, 'volumeClob': 141429.268593, 'liquidityClob': 30420.1094, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0x6df9c389b900084450acb3df5777dcde9ff74f6a1532e9d78a715b5ee83dda00', 'negRiskRequestID': '0xc30a5c5eeca64fff2ee3b61bbb7a83095e36ea93522bcb7f4423640aec4a9baf', '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-11-26T23:46:20Z', 'cyom': False, 'competitive': 0.9577626664112633, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '11097', 'conditionId': '0x5ce0d897bd66142c43a38204a67ad85bc3e0643382258411a5aa58ca3e825082', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 15, 'startDate': '2024-11-29', 'endDate': '2500-12-31'}], 'rewardsMinSize': 20, 'rewardsMaxSpread': 3.5, 'spread': 0.02, 'oneDayPriceChange': -0.015, 'lastTradePrice': 0.29, 'bestBid': 0.28, 'bestAsk': 0.3, 'automaticallyActive': True, 'clearBookOnStart': True, 'seriesColor': '', 'showGmpSeries': False, 'showGmpOutcome': False, 'manualActivation': False, 'negRiskOther': False}, {'id': '514139', 'question': 'Will Rafał Trzaskowski be the next President of Poland?', 'conditionId': '0xd009ac14bccdd12925a2d9f8d910411556e4ed153337abb18a97b97fabcf7db0', 'slug': 'will-rafa-trzaskowski-be-the-next-president-of-poland', 'resolutionSource': '', 'endDate': '2025-05-18T12:00:00Z', 'liquidity': '30449.2482', 'startDate': '2024-11-26T23:39:27.381894Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-rafa-trzaskowski-be-the-next-president-of-poland-idcXVojxVfkb.jpg', 'icon': 'https://p ...
# [{'id': '512832', 'question': 'Will Conor McGregor be the next Prime Minister of Ireland?', 'conditionId': '0x3376277f95016b046ccc398942605382ebce0673ca2934c0732f61ace19ccd06', 'slug': 'will-conor-mcgregor-be-the-next-prime-minister-of-ireland', 'resolutionSource': '', 'endDate': '2024-11-29T12:00:00Z', 'liquidity': '13027.58265', 'startDate': '2024-11-12T16:36:52.848Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-conor-mcgregor-be-the-next-prime-minister-of-ireland-8HP3ukS3UPyD.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-conor-mcgregor-be-the-next-prime-minister-of-ireland-8HP3ukS3UPyD.jpg', 'description': 'The 2024 Irish general election to elect the 34th Dáil is due to be held on Friday, 29 November 2024.\n\nThis market will resolve to "Yes" if Conor McGregor is the next Taoiseach (Prime Minister/Head of State) of Ireland following the election. Otherwise, this market will resolve to "No."\n\nAny interim/caretaker Taoiseach will not count toward the resolution of this market. If no next Taoiseach of Ireland is instated by June 30, of 2025, 11:59 PM ET this market will resolve to "No."\n\nThe primary resolution source for this market will be official information from the Government of Ireland, however a consensus of credible reporting will also be used.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0025", "0.9975"]', 'volume': '9209005.89749609', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-11-12T16:02:50.691391Z', 'updatedAt': '2024-12-22T07:18:49.967269Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Conor McGregor', 'groupItemThreshold': '9', 'questionID': '0x9969b036f214feaf45629c4d56a37cc7812b227ac1aad0901e004c42fe0cd709', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 9209005.89749609, 'liquidityNum': 13027.58265, 'endDateIso': '2024-11-29', 'startDateIso': '2024-11-12', 'hasReviewedDates': True, 'volume24hr': 978.350264, 'clobTokenIds': '["52966854583050241841563802597287557063172002042089904151014136057699421138603", "80487506051978830273534028280198340409062839451472713477847845676674018177268"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 978.350264, 'volumeClob': 9209005.89749609, 'liquidityClob': 13027.58265, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0x9969b036f214feaf45629c4d56a37cc7812b227ac1aad0901e004c42fe0cd700', 'negRiskRequestID': '0x05e274e44561b98f8754e4ae0b2622861c84e1bb4c6f4f3af6a8d62f3a847591', '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-11-12T16:35:41Z', 'cyom': False, 'competitive': 0.8015991903848178, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '10843', 'conditionId': '0x3376277f95016b046ccc398942605382ebce0673ca2934c0732f61ace19ccd06', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 2, 'startDate': '2024-11-22', 'endDate': '2500-12-31'}], 'rewardsMinSize': 20, 'rewardsMaxSpread': 3.5, 'spread': 0.001, 'oneDayPriceChange': 0.0005, 'lastTradePrice': 0.003, 'bestBid': 0.002, 'bestAsk': 0.003, 'automaticallyActive': True, 'clearBookOnStart': True, 'seriesColor': '', 'showGmpSeries': False, 'showGmpOutcome': False, 'manualActivation': True, 'negRiskOther': False}, {'id': '512833', 'question': 'Will Person B be the next Prime Minister of Ireland?', 'conditionId': '0x5fd55f85cd46ae63d69f53a29b94d46550d5550d96e1dd9c1fbe14abd928d1c2', 'slug': 'will-person-b-be-the-next-prime-minister-of-ireland', 'resolutionSource': '', 'endDate': '2024-11-29T12:00:00Z', 'liquidity': '0', 'startDate': '2024-11-12T16:37:24.905Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-jim-ocallaghan-be-the-next-prime-minister-of-ireland-JptSgoTD7Ax6.jpg', 'i ...
# [{'id': '254754', 'question': 'Ethereum all time high in Q1 2024?', 'conditionId': '0xc9c444e3e407a35906fb52d5283aca55f50a070ece8a2fe0d9c6af7ac37cc429', 'slug': 'ethereum-all-time-high-in-q1-2024', 'resolutionSource': 'https://www.binance.com/en/trade/ETH_USDT', 'endDate': '2024-03-31T00:00:00Z', 'startDate': '2024-02-27T19:09:22.149Z', 'fee': '20000000000000000', 'image': "https://polymarket-upload.s3.us-east-2.amazonaws.com/DALL%C2%B7E+2024-02-26+22.30.25+-+Create+an+image+featuring+a+large+Ethereum+symbol+(%CE%9E)+placed+on+a+vibrant+green+arrow+that's+shooting+upwards%2C+symbolizing+the+rapid+growth+and+bullis.webp", 'icon': "https://polymarket-upload.s3.us-east-2.amazonaws.com/DALL%C2%B7E+2024-02-26+22.30.25+-+Create+an+image+featuring+a+large+Ethereum+symbol+(%CE%9E)+placed+on+a+vibrant+green+arrow+that's+shooting+upwards%2C+symbolizing+the+rapid+growth+and+bullis.webp", 'description': 'This market will resolve to "Yes" if Ethereum (ETH) reaches a price greater than $4,891.70 for the first time according to Binance between January 1, 2024, 12:00 AM ET and March 31, 2024, 11:59 PM ET. Otherwise, this market will resolve to "No".\n\nThe resolution source for this market will be the 30-min candlestick high prices from Binance (https://www.binance.com/en/trade/ETH_USDT). If Binance is unavailable, a consensus of other credible sources will be used.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0", "1"]', 'volume': '64914.495934', 'active': True, 'marketType': 'normal', 'closed': True, 'marketMakerAddress': '', 'createdAt': '2024-02-26T21:37:58.692Z', 'updatedAt': '2024-05-07T23:10:07.850213Z', 'closedTime': '2024-04-01 07:50:53+00', 'wideFormat': False, 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Q1', 'groupItemThreshold': '1', 'questionID': '0xc118a2a3329a267db83ab46c68b65c086489a7582b6575a3efa10c89f59cf700', 'umaEndDate': '2024-04-01 07:50:53+00', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'umaResolutionStatus': 'resolved', 'volumeNum': 64914.5, 'endDateIso': '2024-03-31', 'hasReviewedDates': True, 'commentsEnabled': False, 'secondsDelay': 0, 'clobTokenIds': '["96488373959245551780319804892813531836774013944612960450277353053305818446122", "65663339547814364725365017368345299120977019367084003764213543030328495997022"]', 'umaBond': '500.0', 'umaReward': '5.0', 'fpmmLive': True, 'volumeClob': 64914.495934, 'makerBaseFee': 0, 'takerBaseFee': 0, 'customLiveness': 0, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0xc118a2a3329a267db83ab46c68b65c086489a7582b6575a3efa10c89f59cf700', 'negRiskRequestID': '0x2147229429246e9b32ac7c559929ff49bb4d8245d3abcd07e44dac093c28eb9e', 'notificationsEnabled': True, '_sync': True, 'creator': '', 'ready': False, 'funded': False, 'cyom': False, 'pagerDutyNotificationEnabled': False, 'approved': True, 'rewardsMinSize': 0, 'rewardsMaxSpread': 0, 'spread': 1, 'oneDayPriceChange': 0, 'lastTradePrice': 0, 'bestBid': 0, 'bestAsk': 1, 'clearBookOnStart': True, 'manualActivation': False, 'negRiskOther': False}, {'id': '254759', 'question': 'Ethereum all time high in Q4 2024?', 'conditionId': '0xb09684e11fb40f40cfb2fec4a8e08fe2b021a82b0803756a90f04e1364efa94f', 'slug': 'ethereum-all-time-high-in-q4-2024', 'resolutionSource': 'https://www.binance.com/en/trade/ETH_USDT', 'endDate': '2024-12-31T00:00:00Z', 'liquidity': '96884.30769', 'startDate': '2024-02-27T19:09:48.705Z', 'fee': '20000000000000000', 'image': "https://polymarket-upload.s3.us-east-2.amazonaws.com/DALL%C2%B7E+2024-02-26+22.30.25+-+Create+an+image+featuring+a+large+Ethereum+symbol+(%CE%9E)+placed+on+a+vibrant+green+arrow+that's+shooting+upwards%2C+symbolizing+the+rapid+growth+and+bullis.webp", 'icon': "https://polymarket-upload.s3.us-east-2.amazonaws.com/DALL%C2%B7E+2024-02-26+22.30.25+-+Create+an+image+featuring+a+large+Ethe ...
# [{'id': '512704', 'question': 'Will Person A be the next Senate Majority Leader?', 'conditionId': '0x7d4edcbf7f4c115c055e5caca42144e93e59decb3c9993e9d6b3c3e08385f70c', 'slug': 'will-person-a-be-the-next-senate-majority-leader', 'resolutionSource': '', 'endDate': '2025-06-30T12:00:00Z', 'liquidity': '0.05', 'startDate': '2024-11-11T21:58:44.778Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-jd-vance-be-the-next-senate-majority-leader-ZgOhdLV-82X3.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-jd-vance-be-the-next-senate-majority-leader-ZgOhdLV-82X3.jpg', 'description': 'This market will resolve to "Yes" if Person A  is announced as the next Senate Majority Leader after the 2024 U.S. General Election. Otherwise, this market will resolve to "No".\n\nThis market may be updated in the future to replace Person A with one of the potential candidates.\n\nThis market will remain open until January 3, 2025, at which point it will resolve based on the first announcement of the next Senate Majority Leader from whichever party holds the majority in the U.S. Senate.\n\nIf no Majority is established and a leader announced by June, 30, 2025, 11:59 PM, this market will resolve to “No”.\n\n', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.495", "0.505"]', 'active': False, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-11-11T18:08:57.643429Z', 'updatedAt': '2024-11-14T23:02:35.672448Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Person A ', 'groupItemThreshold': '7', 'questionID': '0x72e13dee12e758aba71a2bff3edc745a799c8a7a51af410664851ce681b1500b', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.01, 'orderMinSize': 5, 'liquidityNum': 0.05, 'endDateIso': '2025-06-30', 'startDateIso': '2024-11-11', 'hasReviewedDates': True, 'clobTokenIds': '["103806473583663824489746918308317416606523163537406243047991364446147574904173", "45563080134718104702276270214483117951500723252889665713012229843016601551776"]', 'umaBond': '500', 'umaReward': '5', 'liquidityClob': 0.05, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0x72e13dee12e758aba71a2bff3edc745a799c8a7a51af410664851ce681b15000', 'negRiskRequestID': '0x40a26ae561f9faf2f07c0767ab206ea213d35b437eafe6f9101d54724e41594f', '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-11-11T21:57:33Z', 'cyom': False, 'competitive': 0.009999750006249844, 'pagerDutyNotificationEnabled': False, 'approved': True, 'rewardsMinSize': 0, 'rewardsMaxSpread': 0, 'spread': 0.99, 'bestAsk': 0.99, 'automaticallyActive': True, 'clearBookOnStart': True, 'seriesColor': '', 'showGmpSeries': False, 'showGmpOutcome': False, 'manualActivation': False, 'negRiskOther': False}, {'id': '512706', 'question': 'Will Person B be the next Senate Majority Leader?', 'conditionId': '0xeaee97db8ad9bc06fa5e894e5fa28744bca9626c4937eb0298cc3672c3f59a54', 'slug': 'will-person-b-be-the-next-senate-majority-leader', 'resolutionSource': '', 'endDate': '2025-06-30T12:00:00Z', 'liquidity': '0.05', 'startDate': '2024-11-11T21:58:13.282Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-jd-vance-be-the-next-senate-majority-leader-ZgOhdLV-82X3.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-jd-vance-be-the-next-senate-majority-leader-ZgOhdLV-82X3.jpg', 'description': 'This market will resolve to "Yes" if Person B  is announced as the next Senate Majority Leader after the 2024 U.S. General Election. Otherwise, this market will resolve to "No".\n\nThis market may be updated in the future to replace Person B with one of the potential candidates.\n\nThis market will remain open until January 3, 2025, at which point it will resolve based on the first announcement of the next Senate Majority Leader from whichever party holds the majority i ...
# ...
# [{'id': '253665', 'question': 'Will North Korea invade South Korea in 2024?', 'conditionId': '0xc5db10fafffb5283a093c435ce617a61f0127e3a24a57419e7d25550c6b8df38', 'slug': 'will-north-korea-invade-south-korea-in-2024', 'resolutionSource': '', 'endDate': '2024-12-31T00:00:00Z', 'liquidity': '24605.36846', 'startDate': '2024-01-08T19:58:01.823Z', 'fee': '20000000000000000', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-north-korea-invade-south-korea-in-2024-8fd660ba-eb7a-4426-bd6d-54a52099cc31.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-north-korea-invade-south-korea-in-2024-8fd660ba-eb7a-4426-bd6d-54a52099cc31.png', 'description': 'This market will resolve to "Yes" if North Korea commences a military offensive intended to establish control over any portion of South Korea by December 31, 2024, 11:59 PM ET. Otherwise, this market will resolve to "No".\n\nThe resolution source for this market will be will be official confirmation by North Korea, South Korea, the United Nations, or any permanent member of the UN Security Council, however a consensus of credible reporting will also be used.\n', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0135", "0.9865"]', 'volume': '1132527.219187', 'active': True, 'marketType': 'normal', 'closed': False, 'marketMakerAddress': '0x1a501D276CADA770CEf959Ca749FD4B216256A3c', 'createdAt': '2024-01-08T19:44:15.282Z', 'updatedAt': '2024-12-22T07:18:34.739189Z', 'wideFormat': False, 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '', 'groupItemThreshold': '1', 'questionID': '0x64e589c502ef175eec3eb0475f185c72db8df762c6eeb11ff543d18f1756541f', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 1132527.219187, 'liquidityNum': 24605.36846, 'endDateIso': '2024-12-31', 'startDateIso': '2024-01-08', 'hasReviewedDates': True, 'commentsEnabled': False, 'volume24hr': 13897.330412, 'secondsDelay': 0, 'clobTokenIds': '["29248242988957024957749145407613210275607073690234607747607028828964749034344", "72109158078705258867771471181228659358213309617488586723869844067130786910520"]', 'umaBond': '500.0', 'umaReward': '5.0', 'fpmmLive': True, 'volume24hrClob': 13897.330412, 'volumeClob': 1132527.219187, 'liquidityClob': 24605.36846, 'makerBaseFee': 0, 'takerBaseFee': 0, 'customLiveness': 0, 'acceptingOrders': True, 'notificationsEnabled': True, '_sync': False, 'creator': '', 'ready': False, 'funded': False, 'cyom': False, 'competitive': 0.8086151475045429, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '430', 'conditionId': '0xc5db10fafffb5283a093c435ce617a61f0127e3a24a57419e7d25550c6b8df38', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 5, 'startDate': '2024-04-05', 'endDate': '2500-12-31'}], 'rewardsMinSize': 200, 'rewardsMaxSpread': 3.5, 'spread': 0.001, 'lastTradePrice': 0.013, 'bestBid': 0.013, 'bestAsk': 0.014, 'automaticallyActive': True, 'clearBookOnStart': True, 'manualActivation': False, 'negRiskOther': False}]
# [{'id': '506356', 'question': 'Starmer out as UK prime minister in 2024?', 'conditionId': '0x8a2ae5fe3795afdd425c93105915391ca4a3778e6940970900524ea0166dfab0', 'slug': 'starmer-out-as-uk-prime-minister-in-2024', 'resolutionSource': '', 'endDate': '2024-12-31T12:00:00Z', 'liquidity': '10417.34041', 'startDate': '2024-09-03T23:42:47.953823Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/starmer-out-as-uk-prime-minister-in-2024-cTlH9Z0fk1gl.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/starmer-out-as-uk-prime-minister-in-2024-cTlH9Z0fk1gl.jpg', 'description': 'This market will resolve to “Yes” if Keir Starmer ceases to be the Prime Minister of the United Kingdom for any period of time between September 2, 2024 and December 31, 2024, 11:59 PM ET. Otherwise, this market will resolve to “No”.\n\nThe resolution source for this market will be the government of the UK, however a consensus of credible reporting will also suffice.', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.0075", "0.9925"]', 'volume': '1095338.93981497', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-09-03T20:04:53.351298Z', 'updatedAt': '2024-12-22T07:20:16.400225Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x6A9D222616C90FcA5754cd1333cFD9b7fb6a4F74', 'restricted': True, 'groupItemTitle': '', 'groupItemThreshold': '0', 'questionID': '0x52a58d327986d36d94b6754b2cfdacaf8e9958231eb5d16ab7837a5b5d4f7c29', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.001, 'orderMinSize': 5, 'volumeNum': 1095338.93981497, 'liquidityNum': 10417.34041, 'endDateIso': '2024-12-31', 'startDateIso': '2024-09-03', 'hasReviewedDates': True, 'volume24hr': 656.71, 'clobTokenIds': '["28275425544442560767819765532629949209619217556570057946717108121137817389610", "28345773500556998146383651397223308565200543237819000751322754373508306389870"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 656.71, 'volumeClob': 1095338.93981497, 'liquidityClob': 10417.34041, 'acceptingOrders': True, 'negRisk': False, '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-09-03T23:41:37Z', 'cyom': False, 'competitive': 0.8047925395731582, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '5596', 'conditionId': '0x8a2ae5fe3795afdd425c93105915391ca4a3778e6940970900524ea0166dfab0', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 5, 'startDate': '2024-09-03', 'endDate': '2500-12-31'}], 'rewardsMinSize': 50, 'rewardsMaxSpread': 3.5, 'spread': 0.001, 'oneDayPriceChange': 0.0015, 'lastTradePrice': 0.007, 'bestBid': 0.007, 'bestAsk': 0.008, 'automaticallyActive': True, 'clearBookOnStart': True, 'manualActivation': False, 'negRiskOther': False}]
# [{'id': '514161', 'question': 'Will Union win the most seats in the next German election?', 'conditionId': '0x1921202aa3f884b9c562a244f1e58417d93c9315e6768d27768eb3b2abc2c95b', 'slug': 'will-union-win-the-most-seats-in-the-next-german-election', 'resolutionSource': '', 'endDate': '2025-02-23T12:00:00Z', 'liquidity': '34575.9211', 'startDate': '2024-12-16T18:22:03.444Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-union-win-the-most-seats-in-the-next-german-election-L6eAUWnQyv-X.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-union-win-the-most-seats-in-the-next-german-election-L6eAUWnQyv-X.png', 'description': 'German Federal elections to elect the 21st Bundestag are scheduled to tale place February 23, 2025.\n\nThis market will resolve to "Yes" if Union (Unionsparteien) or CDU/CSU (CDU/CSU-Fraktion im Deutschen Bundestag) wins the most seats in the Bundestag (Germany\'s lower house) as a result of the next German parliamentary election.\n\nIf voting in the next German parliamentary election does not occur by June 30, 2025, this market will resolve to "No".\n\nIn the case of a tie between this party and any other for the most seats gained, this market will resolve in favor of the party whose listed abbreviation comes first in alphabetical order.\n\nThis market\'s resolution will be based solely on the number of seats won by this party, not any coalition of which it may be a part.\n\nThis market will resolve based on the final total number of seats won by each party, including any overhang mandates (Überhangmandate) and balancing mandates (Ausgleichsmandate), as reflected in the official results.\n\nThis market will resolve based on the result of the election as indicated by a consensus of credible reporting. If there is ambiguity, this market will resolve based solely on the official results as reported by the German government, specifically the Federal Returning Officer (Bundeswahlleiter) (https://www.bundeswahlleiterin.de/en/).\n\nNote: The CDU and CSU will be considered a single party, NOT a coalition for the purpose of this market.  ', 'outcomes': '["Yes", "No"]', 'outcomePrices': '["0.885", "0.115"]', 'volume': '114842.624862', 'active': True, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-11-26T18:14:54.301075Z', 'updatedAt': '2024-12-22T07:19:20.273141Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'CDU/CSU', 'groupItemThreshold': '0', 'questionID': '0x22292e9d80e13d13f2f81a2ce6ebec1e44368a5f630acdaf28e4bfa333064e00', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.01, 'orderMinSize': 5, 'volumeNum': 114842.624862, 'liquidityNum': 34575.9211, 'endDateIso': '2025-02-23', 'startDateIso': '2024-12-16', 'hasReviewedDates': True, 'volume24hr': 14947.532715, 'clobTokenIds': '["46170718677339495648435492459077367668216793601074770377073078173626671320755", "102073669368079455662248607998779400621724038228832004867216736035692981690438"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrClob': 14947.532715, 'volumeClob': 114842.624862, 'liquidityClob': 34575.9211, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0x22292e9d80e13d13f2f81a2ce6ebec1e44368a5f630acdaf28e4bfa333064e00', 'negRiskRequestID': '0x0c72d4b32083042fd90dfed26515a0c2db3621d03006ea26874365bf61cc0709', '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-12-16T18:20:53Z', 'cyom': False, 'competitive': 0.8709094471902284, 'pagerDutyNotificationEnabled': False, 'approved': True, 'clobRewards': [{'id': '11781', 'conditionId': '0x1921202aa3f884b9c562a244f1e58417d93c9315e6768d27768eb3b2abc2c95b', 'assetAddress': '0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174', 'rewardsAmount': 0, 'rewardsDailyRate': 70, 'startDate': '2024-12-16', 'endDate': '2500-12-31'}], 'rewardsMinSize': 50, 'rewardsMaxSpread': ...
# [{'id': '513087', 'question': "Will Person E be Trump's HHS Secretary?", 'conditionId': '0xa879902257b91fc52208406ad66c24f723a26781b967258d0d5c7f02fe52db6b', 'slug': 'will-person-e-be-trumps-hhs-secretary', 'resolutionSource': '', 'endDate': '2025-06-30T12:00:00Z', 'liquidity': '0', 'startDate': '2024-11-14T23:25:14.280453Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/who-will-be-trumps-hhs-secretary-LBMD4ejbA87s.jpg', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/who-will-be-trumps-hhs-secretary-LBMD4ejbA87s.jpg', 'description': 'This market will resolve to “Yes” if Donald Trump appoints Person E as Secretary of Health and Human Services by June 30, 2025, 11:59 PM ET. Otherwise, this market will resolve to “No”.\n\nThis market may be updated in the future to replace Person E with one of the potential candidates.\n\nA candidate will be considered to have been appointed if they are confirmed to the position through a senate vote, appointed through a recess appointment, or are otherwise officially made the Secretary of Health and Human Services.\n\nThis market will resolve based on the first Trump candidate who is appointed to this position - if another candidate is appointed to this position first, this market will immediately resolve to "No".\n\nThe resolution source for this market is information from the U.S. Government. ', 'outcomes': '["Yes", "No"]', 'volume': '0', 'active': False, 'closed': False, 'marketMakerAddress': '', 'createdAt': '2024-11-14T23:04:49.300165Z', 'updatedAt': '2024-11-14T23:25:14.280453Z', 'new': False, 'featured': False, 'submitted_by': '0x91430CaD2d3975766499717fA0D66A78D814E5c5', 'archived': False, 'resolvedBy': '0x2F5e3684cb1F318ec51b00Edba38d79Ac2c0aA9d', 'restricted': True, 'groupItemTitle': 'Person E', 'groupItemThreshold': '11', 'questionID': '0x69720e12f0392d24f3ee7bddb68475ac69a37c47b033bb7a799c5797e9f0ed0b', 'enableOrderBook': True, 'orderPriceMinTickSize': 0.01, 'orderMinSize': 5, 'volumeNum': 0, 'liquidityNum': 0, 'volume24hr': 0, 'clobTokenIds': '["18092918590752409888252651283458532854477873621867119813510981887513183024029", "21582744050477958868859437065886237980504871579666666618257860268005269039148"]', 'umaBond': '500', 'umaReward': '5', 'volume24hrAmm': 0, 'volume24hrClob': 0, 'volumeAmm': 0, 'volumeClob': 0, 'liquidityAmm': 0, 'liquidityClob': 0, 'acceptingOrders': True, 'negRisk': True, 'negRiskMarketID': '0x69720e12f0392d24f3ee7bddb68475ac69a37c47b033bb7a799c5797e9f0ed00', 'negRiskRequestID': '0x96b949db54a1f999fd66f0f054188d63ea5626f0a08f81296fe35ce95faf926c', '_sync': False, 'ready': False, 'funded': False, 'acceptingOrdersTimestamp': '2024-11-14T23:24:06Z', 'cyom': False, 'competitive': 0, 'pagerDutyNotificationEnabled': False, 'approved': True, 'rewardsMinSize': 0, 'rewardsMaxSpread': 0, 'spread': 1, 'oneDayPriceChange': 0, 'lastTradePrice': 0, 'bestBid': 0, 'bestAsk': 1, 'automaticallyActive': True, 'clearBookOnStart': True, 'seriesColor': '', 'showGmpSeries': False, 'showGmpOutcome': False, 'manualActivation': True, 'negRiskOther': False}, {'id': '513079', 'question': "Will Eric Hargan be Trump's HHS Secretary?", 'conditionId': '0xb15ee59c1d5a80f8976b191ccc4305738aae2c72c7c9b49d2d47a32332594f15', 'slug': 'will-eric-hargan-be-trumps-hhs-secretary', 'resolutionSource': '', 'endDate': '2025-06-30T12:00:00Z', 'liquidity': '3744.88069', 'startDate': '2024-11-14T23:22:05.545045Z', 'image': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-trump-nominate-eric-hargan-for-hhs-secretary-kH5hUGnfFQEm.png', 'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/will-trump-nominate-eric-hargan-for-hhs-secretary-kH5hUGnfFQEm.png', 'description': 'This market will resolve to “Yes” if Donald Trump appoints Eric Hargan as Secretary of Health and Human Services by June 30, 2025, 11:59 PM ET. Otherwise, this market will resolve to “No”.\n\nA candidate will be considered to have been appointed if they are confirmed to the position through a  ...

# %% [markdown]
# Access the CLIENT CLOB of POLYMARKET to get access to GOLDSKY

# %%
# Standard library imports
import time
import json
from typing import Dict, Any

# Third-party imports
import pandas as pd
import requests
from py_clob_client.client import ClobClient
from dotenv import load_dotenv
import os

# Load environment variables (if you're using .env file for API keys)
load_dotenv('keys/keys.env')


host = "https://clob.polymarket.com"
key = os.getenv("PK")
chain_id = 137  # Polygon Mainnet chain ID

# Ensure the private key is loaded correctly
if not key:
    raise ValueError("Private key not found. Please set PK in the environment variables.")

# Initialize the client with your private key
client = ClobClient(host, key=key, chain_id=chain_id)

# Create or derive API credentials (this is where the API key, secret, and passphrase are generated)
try:
    api_creds = client.create_or_derive_api_creds()
    print("API Key:", api_creds.api_key)
    print("Secret:", api_creds.api_secret)
    print("Passphrase:", api_creds.api_passphrase)

    # You should now save these securely (e.g., store them in your .env file)
except Exception as e:
    print("Error creating or deriving API credentials:", e)

# YOU WILL HAVE TO RUN THIS CODE THE FIRST TIME TO GET THE API KEYS ????
# from py_clob_client.client import ClobClient
# host = "https://clob.polymarket.com"
# private_key = "5c98489d9d3612b7c5f7a91d2c249c808623d212b3266b34deda44480a08b50d"
# chain_id = 137  # Polygon Mainnet
# # Initialize the client with private key
# client = ClobClient(host, key=private_key, chain_id=chain_id)
# api_key_data = client.create_api_key()
# print(api_key_data)
print("Done!")
# Out:
# API Key: 649c5b96-f29f-46c0-421e-9696432f52d4
# Secret: XR9Q5lEpMghhgsGHltR4hUP32Pv3EMoiXN-BaKoMnqs=
# Passphrase: 5c98489d9d3612b7c5f7a91d2c249c808623d212b3266b34deda44480a08b50d
# Done!

# %%
import os
import json
import pandas as pd
from datetime import datetime, timedelta
import requests
import matplotlib.pyplot as plt
# Make sure these imports are at the top of your file
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.patheffects as pe
from matplotlib.ticker import PercentFormatter


class PolymarketDataFetcher:
    def __init__(self):
        self.orders_endpoint = "https://api.goldsky.com/api/public/project_cl6mb8i9h0003e201j6li0diw/subgraphs/polymarket-orderbook-resync/prod/gn"

    def fetch_all_order_history(self, condition_id, start_date="2023-10-08", batch_size=1000):
        """
            Fetch complete order history for a market since a specific date
            
        Args:
            condition_id (str): Market ID
            start_date (str): Start date in YYYY-MM-DD format
            batch_size (int): Number of orders to fetch per request
        """
        all_orders = []
        offset = 0
        
        # Convert start_date to Unix timestamp
        start_timestamp = int(datetime.strptime(start_date, "%Y-%m-%d").timestamp())
        
        while True:
            query = """
            query OrderHistory($conditionId: String!, $limit: Int!, $offset: Int!, $startTime: Int!) {
            enrichedOrderFilleds(
                first: $limit
                skip: $offset
                where: {
                market: $conditionId
                timestamp_gte: $startTime
                }
                orderBy: timestamp
                orderDirection: asc
            ) {
                timestamp
                price
                size
                side
            }
            }
            """
            
            result = self._make_request(query, {
                'conditionId': condition_id,
                'limit': batch_size,
                'offset': offset,
                'startTime': start_timestamp
            })
            
            if not result or 'enrichedOrderFilleds' not in result or not result['enrichedOrderFilleds']:
                break
                
            orders = result['enrichedOrderFilleds']
            all_orders.extend(orders)
            
            print(f"Fetched {len(orders)} orders. Total: {len(all_orders)}")
            
            if len(orders) < batch_size:
                break
                
            offset += batch_size
        
        if not all_orders:
            print("No orders found")
            return None
            
        # Convert to DataFrame
        df = pd.DataFrame(all_orders)
        
        # Convert timestamp to datetime
        df['timestamp'] = pd.to_datetime(df['timestamp'].astype(int), unit='s')
        
        # Convert price and size to numeric
        df['price'] = pd.to_numeric(df['price'])
        df['size'] = pd.to_numeric(df['size'])
        
        # Sort by timestamp
        df = df.sort_values('timestamp')
        
        print(f"\nData range: {df['timestamp'].min()} to {df['timestamp'].max()}")
        
        return df

    def _make_request(self, query, variables):
        try:
            response = requests.post(
                self.orders_endpoint,
                json={'query': query, 'variables': variables}
            )
            response.raise_for_status()
            return response.json().get('data', {})
        except Exception as e:
            print(f"Error making request: {str(e)}")
            return None

def plot_price_history(df, title="Market Price History", resample='1H'):
    """Plot smooth price history with Polymarket-style appearance"""
    # Create figure with white background
    plt.style.use('default')  # Reset to default style
    fig, ax = plt.subplots(figsize=(15, 8))
    
    # Resample data to smooth the line
    df_resampled = df.set_index('timestamp').resample(resample).agg({
        'price': 'last',
        'size': 'sum'
    }).fillna(method='ffill')
    
    # Plot the price line with smoothing
    ax.plot(df_resampled.index, df_resampled['price'], 
            color='#0066FF',  # Polymarket blue
            linewidth=2,
            solid_capstyle='round',
            path_effects=[pe.SimpleLineShadow(shadow_color='gray', alpha=0.2),
                         pe.Normal()])
    
    # Add subtle grid
    ax.grid(True, linestyle='--', alpha=0.2, color='gray')
    ax.set_facecolor('white')
    fig.patch.set_facecolor('white')
    
    # Format x-axis to show dates nicely
    ax.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
    plt.xticks(rotation=0)
    
    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_alpha(0.3)
    ax.spines['bottom'].set_alpha(0.3)
    
    # Add subtle source attribution
    plt.text(0.01, 0.02, 'Source: Polymarket.com', 
             transform=ax.transAxes, 
             color='gray', 
             alpha=0.6,
             fontsize=8)
    
    # Adjust layout
    plt.tight_layout()
    
    return fig

if __name__ == "__main__":
    fetcher = PolymarketDataFetcher()
    
    # Your market ID
    clobTokenId = "55223339147513557002753346210723654663683660449692044699329423663012565950662"
    
    print("\nFetching complete order history since Oct 8...")
    df = fetcher.fetch_all_order_history(
        clobTokenId,
        start_date="2023-10-08",  # Specify the start date here
        batch_size=1000
    )
    
    if df is not None:
        # Save raw data
        df.to_csv(f'price_history_{clobTokenId[-8:]}.csv', index=False)
        print(f"\nData saved to price_history_{clobTokenId[-8:]}.csv")
        
        # Create price history plot
        fig = plot_price_history(df, resample='1H')  # Adjust resampling as needed
        
        # Save plot
        fig.savefig(f'price_history_{clobTokenId[-8:]}.png')
        print(f"Plot saved to price_history_{clobTokenId[-8:]}.png")
# Out:
# Fetching complete order history since Oct 8...
# Fetched 1000 orders. Total: 1000
# Fetched 1000 orders. Total: 2000
# Fetched 1000 orders. Total: 3000
# Fetched 1000 orders. Total: 4000
# Fetched 1000 orders. Total: 5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 162
#     159 clobTokenId = "55223339147513557002753346210723654663683660449692044699329423663012565950662"
#     161 print("\nFetching complete order history since Oct 8...")
# --> 162 df = fetcher.fetch_all_order_history(
#     163     clobTokenId,
#     164     start_date="2023-10-08",  # Specify the start date here
#     165     batch_size=1000
#     166 )
#     168 if df is not None:
#     169     # Save raw data
#     170     df.to_csv(f'price_history_{clobTokenId[-8:]}.csv', index=False)
#
# Cell In[17], line 54, in PolymarketDataFetcher.fetch_all_order_history(self, condition_id, start_date, batch_size)
#      33 while True:
#      34     query = """
#      35     query OrderHistory($conditionId: String!, $limit: Int!, $offset: Int!, $startTime: Int!) {
#      36     enrichedOrderFilleds(
#    (...)
#      51     }
#      52     """
# ---> 54     result = self._make_request(query, {
#      55         'conditionId': condition_id,
#      56         'limit': batch_size,
#      57         'offset': offset,
#      58         'startTime': start_timestamp
#      59     })
#      61     if not result or 'enrichedOrderFilleds' not in result or not result['enrichedOrderFilleds']:
#      62         break
#
# Cell In[17], line 97, in PolymarketDataFetcher._make_request(self, query, variables)
#      95 def _make_request(self, query, variables):
#      96     try:
# ---> 97         response = requests.post(
#      98             self.orders_endpoint,
#      99             json={'query': query, 'variables': variables}
#     100         )
#     101         response.raise_for_status()
#     102         return response.json().get('data', {})
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/miniconda3/envs/myenv/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/miniconda3/envs/myenv/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/myenv/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File ~/miniconda3/envs/myenv/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/myenv/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:
